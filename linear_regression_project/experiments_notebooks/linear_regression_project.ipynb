# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv(r"C:\Users\USER\Desktop\data science\linear_regression_project\raw_data\indian_engineering_student_placement (1).csv")

# %%
y = pd.read_csv(r"C:\Users\USER\Desktop\data science\linear_regression_project\raw_data\placement_targets.csv")

# %%
X.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
#    ...  aptitude_skill_rating  hackathons_participated  certifications_count  \
# 0  ...                      5                        4                     5
# 1  ...                      3                        4                     1
# 2  ...                      4                        6                     3
# 3  ...                      4                        2                     2
# 4  ...                      3                        2                     1
#
#    sleep_hours  stress_level  part_time_job  family_income_level  city_tier  \
# 0          6.5             8            Yes               Medium     Tier 2
# 1          7.1             8            Yes               Medium     Tier 3
# 2          6.1             2             No                  Low     Tier 2
# 3          7.3             7             No               Medium     Tier 1
# 4          6.0             7             No               Medium     Tier 1
#
#   internet_access extracurricular_involvement
# 0             Yes                      Medium
# 1             Yes                         Low
# 2             Yes                        High
# 3             Yes                         Low
# 4             Yes                      Medium
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
#    Student_ID placement_status  salary_lpa
# 0           1           Placed       14.95
# 1           2           Placed       14.91
# 2           3           Placed       17.73
# 3           4           Placed       14.52
# 4           5           Placed       15.91

# %%
X=X.drop(['Student_ID','extracurricular_involvement'], axis = 1)
y=y.drop(['Student_ID', 'placement_status'],axis = 1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      5000 non-null   object
#  1   branch                      5000 non-null   object
#  2   cgpa                        5000 non-null   float64
#  3   tenth_percentage            5000 non-null   float64
#  4   twelfth_percentage          5000 non-null   float64
#  5   backlogs                    5000 non-null   int64
#  6   study_hours_per_day         5000 non-null   float64
#  7   attendance_percentage       5000 non-null   float64
#  8   projects_completed          5000 non-null   int64
#  9   internships_completed       5000 non-null   int64
#  10  coding_skill_rating         5000 non-null   int64
#  11  communication_skill_rating  5000 non-null   int64
#  12  aptitude_skill_rating       5000 non-null   int64
#  13  hackathons_participated     5000 non-null   int64
#  14  certifications_count        5000 non-null   int64
#  15  sleep_hours                 5000 non-null   float64
#  16  stress_level                5000 non-null   int64
#  17  part_time_job               5000 non-null   object
#  18  family_income_level         5000 non-null   object
#  19  city_tier                   5000 non-null   object
#  20  internet_access             5000 non-null   object
# dtypes: float64(6), int64(9), object(6)
# memory usage: 820.4+ KB

# %% [markdown]
# train  test and split

# %%
train_test_split(X, y, test_size=0.2)
# Out:
# [      gender branch   cgpa  tenth_percentage  twelfth_percentage  backlogs  \
#  1986  Female    ECE   8.81              84.2                70.7         1
#  3293    Male    CSE  10.00              90.7                84.8         0
#  661   Female    CSE   7.82              72.1                66.5         0
#  932   Female    CSE   9.24              89.0                90.0         0
#  2842  Female    CSE   7.73              73.1                65.9         1
#  ...      ...    ...    ...               ...                 ...       ...
#  3789  Female     ME   8.23              72.9                69.2         0
#  2644    Male    CSE   7.72              71.4                69.9         0
#  625     Male     IT   8.41              75.4                79.5         2
#  3731  Female     CE   8.38              78.9                79.8         0
#  1854  Female    CSE   6.90              64.1                65.7         0
#
#        study_hours_per_day  attendance_percentage  projects_completed  \
#  1986                  4.3                   77.6                   6
#  3293                  6.0                   77.4                   8
#  661                   2.4                   70.4                   4
#  932                   8.4                   81.8                   5
#  2842                  2.6                   65.8                   7
#  ...                   ...                    ...                 ...
#  3789                  4.5                   79.2                   1
#  2644                  1.0                   52.6                   7
#  625                   3.1                   66.6                   5
#  3731                  5.9                   79.7                   2
#  1854                  3.0                   69.3                   8
#
#        internships_completed  ...  communication_skill_rating  \
#  1986                      3  ...                           4
#  3293                      4  ...                           1
#  661                       2  ...                           1
#  932                       2  ...                           1
#  2842                      3  ...                           1
#  ...                     ...  ...                         ...
#  3789                      1  ...                           2
#  2644                      2  ...                           2
#  625                       2  ...                           1
#  3731                      3  ...                           4
#  1854                      0  ...                           1
#
#        aptitude_skill_rating  hackathons_participated  certifications_count  \
#  1986                      4                        6                     3
#  3293                      4                        4                     6
#  661                       3                        2                     4
#  932                       5                        3                     2
#  2842                      4                        5                     1
#  ...                     ...                      ...                   ...
#  3789                      4                        2                     2
#  2644                      4                        3                     2
#  625                       5                        5                     0
#  3731                      4                        1                     0
#  1854                      4                        6                     4
#
#        sleep_hours  stress_level  part_time_job family_income_level city_tier  \
#  1986          6.3             4             No                 Low    Tier 1
#  3293          6.4             5             No                 Low    Tier 2
#  661           6.7             7            Yes                 Low    Tier 1
#  932           5.8            10            Yes                 Low    Tier 3
#  2842          7.2             1             No              Medium    Tier 3
#  ...           ...           ...            ...                 ...       ...
#  3789          6.6             1             No              Medium    Tier 2
#  2644          5.8            10            Yes              Medium    Tier 3
#  625           6.1             7            Yes              Medium    Tier 2
#  3731          8.0             4            Yes              Medium    Tier 3
#  1854          7.7             1             No              Medium    Tier 3
#
#       internet_access
#  1986              No
#  3293             Yes
#  661              Yes
#  932              Yes
#  2842             Yes
#  ...              ...
#  3789             Yes
#  2644             Yes
#  625              Yes
#  3731             Yes
#  1854             Yes
#
#  [4000 rows x 21 columns],
#        gender branch   cgpa  tenth_percentage  twelfth_percentage  backlogs  \
#  2790  Female    ECE   7.28              64.4                61.6         0
#  3266    Male     ME  10.00              91.0                84.5         0
#  2446    Male     ME   9.55              77.6                87.9         2
#  1209  Female    CSE   8.64              82.0                75.5         0
#  3782    Male    ECE   8.97              73.0                82.3         1
#  ...      ...    ...    ...               ...                 ...       ...
#  4556  Female    CSE   7.25              71.8                62.4         0
#  2076    Male     ME   8.30              76.7                74.4         0
#  2970    Male     IT   9.19              84.1                84.5         0
#  4107    Male     IT   8.41              69.6                67.2         0
#  4230  Female    ECE   7.28              66.0                56.8         0
#
#        study_hours_per_day  attendance_percentage  projects_completed  \
#  2790                  2.7                   68.3                   5
#  3266                  4.5                   79.2                   2
#  2446                  3.3                   74.2                   6
#  1209                  4.9                   72.5                   8
#  3782                  5.8                   76.7                   8
#  ...                   ...                    ...                 ...
#  4556                  2.2                   64.0                   6
#  2076                  4.0                   69.3                   7
#  2970                  3.7                   77.4                   5
#  4107                  3.9                   83.8                   3
#  4230                  2.2                   65.9                   7
#
#        internships_completed  ...  communication_skill_rating  \
#  2790                      1  ...                           2
#  3266                      4  ...                           5
#  2446                      3  ...                           4
#  1209                      1  ...                           4
#  3782                      2  ...                           1
#  ...                     ...  ...                         ...
#  4556                      2  ...                           4
#  2076                      1  ...                           4
#  2970                      2  ...                           2
#  4107                      0  ...                           5
#  4230                      2  ...                           4
#
#        aptitude_skill_rating  hackathons_participated  certifications_count  \
#  2790                      4                        2                     1
#  3266                      5                        4                     2
#  2446                      5                        1                     1
#  1209                      4                        5                     1
#  3782                      5                        5                     5
#  ...                     ...                      ...                   ...
#  4556                      4                        6                     2
#  2076                      4                        4                     4
#  2970                      5                        3                     2
#  4107                      4                        2                     5
#  4230                      4                        3                     7
#
#        sleep_hours  stress_level  part_time_job family_income_level city_tier  \
#  2790          6.5             1             No                 Low    Tier 3
#  3266          5.4             3             No                 Low    Tier 2
#  2446          8.3             7             No              Medium    Tier 1
#  1209          8.0             2             No              Medium    Tier 2
#  3782          6.6             5             No              Medium    Tier 1
#  ...           ...           ...            ...                 ...       ...
#  4556          6.8             1             No              Medium    Tier 2
#  2076          8.5             8             No                 Low    Tier 1
#  2970          6.9            10             No              Medium    Tier 1
#  4107          5.9             5             No                 Low    Tier 1
#  4230          6.9            10            Yes                 Low    Tier 2
#
#       internet_access
#  2790             Yes
#  3266             Yes
#  2446             Yes
#  1209             Yes
#  3782             Yes
#  ...              ...
#  4556             Yes
#  2076             Yes
#  2970             Yes
#  4107             Yes
#  4230             Yes
#
#  [1000 rows x 21 columns],
#        salary_lpa
#  1986       18.03
#  3293       20.00
#  661        12.64
#  932        18.65
#  2842        0.00
#  ...          ...
#  3789       11.08
#  2644       16.85
#  625        14.89
#  3731       11.55
#  1854       12.87
#
#  [4000 rows x 1 columns],
#        salary_lpa
#  2790       12.22
#  3266       20.00
#  2446       15.25
#  1209       18.49
#  3782       17.91
#  ...          ...
#  4556       16.92
#  2076       13.03
#  2970       18.52
#  4107       13.22
#  4230       13.92
#
#  [1000 rows x 1 columns]]
