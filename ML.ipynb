# %%
# regression == > numeric > score
# classification == > categorical > yes/no

# %%
# load data
# clean data
# anayze the data
# train test data
# feature engineering/ data preprocessing 
# fetaure selction
# model selection
# model train
# model test
