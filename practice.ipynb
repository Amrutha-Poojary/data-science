# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
normal_dist_data = np.random.normal(0,1,100)
normal_dist_data
# Out:
# array([-0.58069555, -0.62303687, -0.16161846,  0.57053177,  0.51524842,
#        -1.6876227 ,  1.9256801 ,  0.65217133,  1.46453909, -0.07913998,
#        -1.01910352, -0.40538251, -0.05101325,  0.93367921, -0.5046838 ,
#         0.0235697 ,  0.91572685,  1.62491128, -0.17630266,  1.35146131,
#        -0.42962164, -0.15676293,  0.63620201,  0.22723154, -1.09774098,
#        -1.49066806,  0.63043432, -0.02718539, -0.64488014, -0.61829076,
#         1.52764882, -1.08460726, -1.48997531,  0.75074287,  0.43262365,
#         0.32431257,  0.76240591, -0.32064967,  2.1358331 ,  0.7166834 ,
#        -0.71882102, -1.62504093,  0.78619146,  0.27616187, -0.32167713,
#        -0.70886138, -1.02972793, -0.04007548,  0.40012657,  0.52400936,
#         0.64557071, -1.09075424, -0.67749324, -0.29888157, -0.49193957,
#         0.50725712, -0.42960841,  0.81960161,  0.363688  , -0.35485719,
#        -0.3489853 , -1.0827305 ,  0.74593889, -0.60882465, -1.12002767,
# ...

# %%
sns.displot(normal_dist_data, kde=True)

# %%
exp_dist_data = np.random.exponential(4,100)

# %%
sns.displot(exp_dist_data, kde=True)

# %%
uniform_dist_data = np.random.uniform(1,6,100)

# %%
sns.displot(uniform_dist_data, kde = True)

# %%
import seaborn as sns
import pandas as pd

# %%
rating_df = pd.read_csv(r"C:\Users\USER\Downloads\rating_missing_data.csv")

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2580 non-null   int64
#  1   Review #    2322 non-null   float64
#  2   Brand       2322 non-null   object
#  3   Variety     2322 non-null   object
#  4   Style       2322 non-null   object
#  5   Country     2322 non-null   object
#  6   Stars       2322 non-null   object
#  7   Top Ten     35 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 161.4+ KB

# %%
rating_df.isnull().sum()/2580*100
# Out:
# Unnamed: 0     0.000000
# Review #      10.000000
# Brand         10.000000
# Variety       10.000000
# Style         10.000000
# Country       10.000000
# Stars         10.000000
# Top Ten       98.643411
# dtype: float64

# %%
(258/2580)*100
# Out:
# 10.0

# %% [markdown]
# KNN imputation

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
rating_df['Stars']
from sklearn.impute import KNNImputer

knn_imputer =KNN
# Out:
# 0       3.75
# 1          1
# 2       2.25
# 3       2.75
# 4       3.75
#         ...
# 2575     3.5
# 2576       1
# 2577       2
# 2578     NaN
# 2579     0.5
# Name: Stars, Length: 2580, dtype: object

# %%
placement_df = pd.read_csv(r"C:\Users\USER\Downloads\indian_engineering_student_placement.csv")
