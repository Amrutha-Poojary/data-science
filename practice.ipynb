# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
normal_dist_data = np.random.normal(0,1,100)
normal_dist_data
# Out:
# array([ 0.56799157, -0.60905102, -0.20799142,  0.45123055, -0.14490009,
#        -0.67180518,  1.3230613 ,  1.83016909,  0.51060728,  0.09375013,
#         0.42990082, -0.13312106, -0.55511394, -0.48497999, -0.62077969,
#        -0.20290771,  0.0789088 , -0.41544903,  0.09513583,  1.48344075,
#         1.12712189, -0.46201746, -0.99871744,  0.20047898, -0.80909435,
#        -0.1315003 , -0.01767048,  1.62921575, -1.27539798, -0.35811453,
#         0.17320685, -1.64757578,  1.06983606,  2.23788828,  0.37252449,
#         1.65359737, -0.11709115, -0.02525799, -1.00347599, -0.79974963,
#         0.45719758,  0.61122645,  0.6223792 ,  0.09335579,  1.43508788,
#        -0.41248289, -0.47008507, -0.89829395,  1.42114806,  0.02742149,
#         0.0917849 , -0.90703604, -0.12452078, -0.9968693 , -0.35455555,
#         0.58108838,  0.43554825,  0.33865685,  1.46212059,  1.01848185,
#         0.14195671,  0.35532154, -0.37034724, -0.41282811, -1.93107735,
#         0.37726187, -3.14420227, -0.33824135, -1.07858178, -1.01087516,
#        -0.65186646,  0.13493037,  0.40089238, -0.32049128, -1.60477055,
#        -0.26300373,  0.18117148,  0.81423809, -0.53949357,  0.86301976,
#        -0.05369039,  2.47749061,  0.37902058,  1.18249157,  0.27561778,
#         1.65940999,  0.14597184,  0.7260452 ,  0.89750458,  0.33130706,
#        -0.26840042,  0.03912243, -0.46502425, -0.08277347,  0.24894515,
#        -0.19947023, -0.05375121,  0.02880345, -0.68322772,  0.39253068])

# %%
sns.displot(normal_dist_data, kde=True)

# %%
exp_dist_data = np.random.exponential(4,100)

# %%
sns.displot(exp_dist_data, kde=True)

# %%
uniform_dist_data = np.random.uniform(1,6,100)

# %%
sns.displot(uniform_dist_data, kde = True)

# %%
import seaborn as sns
import pandas as pd

# %%
rating_df = pd.read_csv(r"C:\Users\USER\Downloads\rating_missing_data.csv")

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2580 non-null   int64
#  1   Review #    2322 non-null   float64
#  2   Brand       2322 non-null   object
#  3   Variety     2322 non-null   object
#  4   Style       2322 non-null   object
#  5   Country     2322 non-null   object
#  6   Stars       2322 non-null   object
#  7   Top Ten     35 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 161.4+ KB

# %%
rating_df.isnull().sum()/2580*100
# Out:
# Unnamed: 0     0.000000
# Review #      10.000000
# Brand         10.000000
# Variety       10.000000
# Style         10.000000
# Country       10.000000
# Stars         10.000000
# Top Ten       98.643411
# dtype: float64

# %%
(258/2580)*100
# Out:
# 10.0
